# %%
import os
import pandas as pd

master_df = pd.DataFrame()

for file in os.listdir(f'{os.getcwd()}/Car_Hire_Data'):
    master_df = pd.concat([master_df, pd.read_csv(f'./Car_Hire_Data/{file}')],  ignore_index=True)

master_df.to_csv('CarHireData.csv')

master_df.head()
# Out:
#      City Car Type  Number of Passengers                            Location  \
# 0  Dublin  Ford Ka                   4.0  Q-park, Marlborough Street, Dublin
# 1  Dublin  Ford Ka                   4.0  Q-park, Marlborough Street, Dublin
# 2  Dublin  Ford Ka                   4.0  Q-park, Marlborough Street, Dublin
# 3  Dublin  Ford Ka                   4.0  Q-park, Marlborough Street, Dublin
# 4  Dublin  Ford Ka                   4.0  Q-park, Marlborough Street, Dublin
#
#           Supplier  Total Price  Price  Offer Rating
# 0  EconomyBookings         82.0   21.0           8.2
# 1             Sixt         83.0   21.0           8.5
# 2         Bsp Auto         86.0   22.0           9.0
# 3       Rentalcars        107.0   27.0           7.8
# 4      Booking.com        107.0   27.0           7.8

# %%
master_df['Number of Passengers'] = master_df['Number of Passengers'].astype('Int64')

master_df['Total Price'] = master_df['Total Price'].astype('Int64')

master_df['Price'] = master_df['Price'].astype('Int64')

master_df.head()
# Out:
#      City Car Type  Number of Passengers                            Location  \
# 0  Dublin  Ford Ka                     4  Q-park, Marlborough Street, Dublin
# 1  Dublin  Ford Ka                     4  Q-park, Marlborough Street, Dublin
# 2  Dublin  Ford Ka                     4  Q-park, Marlborough Street, Dublin
# 3  Dublin  Ford Ka                     4  Q-park, Marlborough Street, Dublin
# 4  Dublin  Ford Ka                     4  Q-park, Marlborough Street, Dublin
#
#           Supplier  Total Price  Price  Offer Rating
# 0  EconomyBookings           82     21           8.2
# 1             Sixt           83     21           8.5
# 2         Bsp Auto           86     22           9.0
# 3       Rentalcars          107     27           7.8
# 4      Booking.com          107     27           7.8

# %%
master_df.to_csv('CarHireDataCleaned.csv', index=False)
